# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd

def evaluate(y_true, pred):
    print("MAE :", mean_absolute_error(y_true, pred))
    print("RMSE:", np.sqrt(mean_squared_error(y_true, pred)))
    print("R²  :", r2_score(y_true, pred))


#evaluate(y_test, pred_lr)

# %%
# %whos
# Out:
# Variable              Type        Data/Info
# -------------------------------------------
# evaluate              function    <function evaluate at 0x000002AC4ACA2DE0>
# mean_absolute_error   function    <function mean_absolute_e<...>or at 0x000002AC4AB42020>
# mean_squared_error    function    <function mean_squared_er<...>or at 0x000002AC4AB423E0>
# np                    module      <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# r2_score              function    <function r2_score at 0x000002AC4AB42C00>

# %%
evaluate(y_test, pred_lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 evaluate(y_test, pred_lr)
#
# NameError: name 'y_test' is not defined

# %%
print("y_test exists:", "y_test" in locals())
print("pred_lr exists:", "pred_lr" in locals())
print("evaluate exists:", "evaluate" in locals())

if "pred_lr" in locals():
    print(type(pred_lr), len(pred_lr))
# Out:
# y_test exists: False
# pred_lr exists: False
# evaluate exists: True

# %%
print("X_train" in locals())
print("X_test" in locals())
print("y_train" in locals())
print("y_test" in locals())
print("pred_lr" in locals())
# Out:
# False
# False
# False
# False
# False

# %%
evaluate(y_test, pred_lr)

evaluate(y_test, pred_dt)

evaluate(y_test, pred_rf)

evaluate(y_test, pred_xgb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 evaluate(y_test, pred_lr)
#       2
#       3 evaluate(y_test, pred_dt)
#       4
#
# NameError: name 'y_test' is not defined
